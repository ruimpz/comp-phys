# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
r = np.arange(1, 4, .001)
x = .0 * r + .5
it = 1000

for i in range(it):
    x = r * x * (1 - x)

plt.scatter(r, x)
