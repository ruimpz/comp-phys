# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def r(x, y, h):
    return np.sqrt(x*x + (y - h)**2)

def f(h, r, lamb, sigma):
    return np.exp( -h*h/(2 * sigma*sigma) + 2*np.pi * r / lamb * 1j ) / r

def simpson(f, a, b, N):
    N = N // 2 * 2
    h = (b - a)/N
    i = np.linspace(a, b, N + 1)
    j = f(x, i, h)
    return h / 3 * (y[0] + y[-1] + 4*y[1:-1:2].sum() + 2*y[2:-1:2].sum())

# %%
print(simpson(f, -10, 10, ))
