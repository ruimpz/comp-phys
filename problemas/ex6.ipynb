# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def catalan(n):
    if n == 0:
        return 1
    else:
        return (4 * n - 2) / (n + 1) * catalan(n - 1)

# %%
print(catalan(100))
# Out:
# 8.965199470901317e+56

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def g(m, n):
    if n == 0:
        return m
    else:
        return g(n, m % n)

# %%
print(g(108, 192))
# Out:
# 12
