# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def binomial(n, k):
    result = 1
    while k > 0:
        result *= (n - k + 1) / (k)
        k -= 1
    return int(result)

# %%
#Verificamos que binomial é 1 quando k = 0
binomial(42, 0)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
L = 20

def pascal(L):
    for i in range(1, L):
        for space in range(L - i - 1):
            print(" ", end="")
        for j in range(i - 1):
            print("{} ".format(binomial(i, j)), end="")
        print(1, end="")
        for space in range(L - i - 1):
            print(" ", end="")
        print()

# %%
#Only works for numbers below 10, because I'm dumb.
pascal(5)
# Out:
#    1
#   1 1
#  1 3 1
# 1 4 6 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# (a)
P = binomial(100, 60) / 2**100
print(P)
# Out:
# 0.010843866711637985

# %%
# (b)
x = 0
for k in range(60, 101):
    x += binomial(100, k)
P = x / (2 ** 100)
print(P)
# Out:
# 0.028443966820490392
