# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt

def f(x):
    return sqrt(1 - x**2)

def integral(a, b, N):
    h = (b - a)/N + f(b)
    s = 0
    for n in range(1, N):
        s += h * f(a + h * n)
    return s

# %%
N = 1000000
a = -1
b = 1

# %%
print(integral(a, b, N))
# Out:
# 1.5707963251317274
