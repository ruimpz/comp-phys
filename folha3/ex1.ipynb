# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    result = 1
    while n > 1:
        result *= n
        n -= 1
    return result

# %%
n = int(input("n = "))
print(factorial(n))
# Out:
# n = 200
# 

# %%
n = float(input("n = "))
print(factorial(n))
# Out:
# n = 200
# inf
